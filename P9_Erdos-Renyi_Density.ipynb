# %%
import networkx as nx

# %%
#Creating a Random Graph with 10 nodes using Erdos-Renyi Model
G = nx.erdos_renyi_graph(10, p=0.3, directed=False)

nx.draw(G, with_labels=True)

# %%
#Finding the Density of the Graph
print(nx.density(G))
# Out:
# 0.4
